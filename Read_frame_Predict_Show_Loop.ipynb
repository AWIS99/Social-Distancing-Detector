# %%
import numpy as np
import cv2

import keras
from keras.models import load_model

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import PIL

import math
import time

# %%
model = load_model('model.h5')
# Out:
# /home/awis/anaconda3/envs/tensorflow_env/lib/python3.7/site-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
def load_image_pixels(filename, shape):
    height, width, c = filename.shape
    # load the image with the required size
    image = cv2.resize(filename, shape)
    print("Frame_Feed_To_Model  :",image.shape)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0
    # add a dimension so that we have one sample
    image = np.expand_dims(image, 0)
    return image, width, height

class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        self.objness = objness
        self.classes = classes
        self.label = -1
        self.score = -1
 
    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
 
        return self.label
 
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
 
        return self.score
 
def _sigmoid(x):
    return 1. / (1. + np.exp(-x))
 
def decode_netout(netout, anchors, obj_thresh, net_h, net_w):
    grid_h, grid_w = netout.shape[:2]
    nb_box = 3
    netout = netout.reshape((grid_h, grid_w, nb_box, -1))
    nb_class = netout.shape[-1] - 5
    boxes = []
    netout[..., :2]  = _sigmoid(netout[..., :2])
    netout[..., 4:]  = _sigmoid(netout[..., 4:])
    netout[..., 5:]  = netout[..., 4][..., np.newaxis] * netout[..., 5:]
    netout[..., 5:] *= netout[..., 5:] > obj_thresh
 
    for i in range(grid_h*grid_w):
        row = i / grid_w
        col = i % grid_w
        for b in range(nb_box):
            # 4th element is objectness score
            objectness = netout[int(row)][int(col)][b][4]
            if(objectness.all() <= obj_thresh): continue
            # first 4 elements are x, y, w, and h
            x, y, w, h = netout[int(row)][int(col)][b][:4]
            x = (col + x) / grid_w # center position, unit: image width
            y = (row + y) / grid_h # center position, unit: image height
            w = anchors[2 * b + 0] * np.exp(w) / net_w # unit: image width
            h = anchors[2 * b + 1] * np.exp(h) / net_h # unit: image height
            # last elements are class probabilities
            classes = netout[int(row)][col][b][5:]
            box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, objectness, classes)
            boxes.append(box)
    return boxes
 
def correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w):
    new_w, new_h = net_w, net_h
    for i in range(len(boxes)):
        x_offset, x_scale = (net_w - new_w)/2./net_w, float(new_w)/net_w
        y_offset, y_scale = (net_h - new_h)/2./net_h, float(new_h)/net_h
        boxes[i].xmin = int((boxes[i].xmin - x_offset) / x_scale * image_w)
        boxes[i].xmax = int((boxes[i].xmax - x_offset) / x_scale * image_w)
        boxes[i].ymin = int((boxes[i].ymin - y_offset) / y_scale * image_h)
        boxes[i].ymax = int((boxes[i].ymax - y_offset) / y_scale * image_h)
 
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3
 
def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    intersect = intersect_w * intersect_h
    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    union = w1*h1 + w2*h2 - intersect
    return float(intersect) / union
 
def do_nms(boxes, nms_thresh):
    if len(boxes) > 0:
        nb_class = len(boxes[0].classes)
    else:
        return
    for c in range(nb_class):
        sorted_indices = np.argsort([-box.classes[c] for box in boxes])
        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            if boxes[index_i].classes[c] == 0: continue
            for j in range(i+1, len(sorted_indices)):
                index_j = sorted_indices[j]
                if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_thresh:
                    boxes[index_j].classes[c] = 0
                    
# define the labels
labels = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck",
    "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench",
    "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe",
    "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard",
    "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard",
    "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana",
    "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake",
    "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse",
    "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator",
    "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]

def get_boxes(boxes, labels, thresh):
    v_boxes, v_labels, v_scores = list(), list(), list()
    # enumerate all boxes
    for box in boxes:
        # enumerate all possible labels
        for i in range(len(labels)):
            # check if the threshold for this label is high enough
            if box.classes[i] > thresh:
                v_boxes.append(box)
                v_labels.append(labels[i])
                v_scores.append(box.classes[i]*100)
                # don't break, many labels may trigger for one box
    return v_boxes, v_labels, v_scores
 
# draw all results
def draw_boxes(frame, v_boxes, v_labels, v_scores, min_dist):
    cal_point=[]
    for i in range(len(v_boxes)):
        box = v_boxes[i]
        # get coordinates
        y1, x1, y2, x2 = box.ymin, box.xmin, box.ymax, box.xmax
        width, height = x2 - x1, y2 - y1
        mid_x, mid_y = (width//2)+x1, y2
        cal_point.append((mid_x,mid_y))
        frame = cv2.rectangle(frame, (x1,y1), (x2,y2), (255,255,0), 1)
        label = "%s (%.3f) %s" % (v_labels[i], v_scores[i], i)
        t_point_x=x1-14
        t_point_y=y1-3
        frame = cv2.putText(frame, label, (t_point_x,t_point_y), cv2.FONT_HERSHEY_SIMPLEX, 0.35, color=(255,255,255), thickness=1)

    print("\nMid point coordinates :")
    print(cal_point,"\n")
    for i in range(len(cal_point)):
        for j in range(i+1,len(cal_point)):
            d=round(math.sqrt(math.pow(cal_point[j][0]-cal_point[i][0],2)+math.pow(cal_point[j][1]-cal_point[i][1],2)),3)
            print("boxes :", i,":", j,"Distance :", d)
            if(d<=min_dist):
                box_i,box_j = v_boxes[i],v_boxes[j]
                y1i, x1i, y2i, x2i = box_i.ymin, box_i.xmin, box_i.ymax, box_i.xmax
                y1j, x1j, y2j, x2j = box_j.ymin, box_j.xmin, box_j.ymax, box_j.xmax
                frame = cv2.rectangle(frame, (x1i,y1i), (x2i,y2i), (0,0,255), 1)
                frame = cv2.rectangle(frame, (x1j,y1j), (x2j,y2j), (0,0,255), 1)

# %%
video = "sample.mp4"
cap = cv2.VideoCapture(video)

# Check if video file is opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")

anchors = [[116,90, 156,198, 373,326], [30,61, 62,45, 59,119], [10,13, 16,30, 33,23]]
# define the probability threshold for detected objects
class_threshold = 0.6
boxes = list()
rem=list()

while(cap.isOpened()):
    # record start time
    start=time.time()
    
    ret, frame = cap.read()
    frame = cv2.resize(frame, (960, 540))
    
    print("\nCaptured_frame_shape :",frame.shape)
    input_w, input_h = 416, 416
    image, image_w, image_h = load_image_pixels(frame, (input_w, input_h))
    
    yhat = model.predict(image)
    print([a.shape for a in yhat])
    
    # decode the output of the network
    for i in range(len(yhat)):
        boxes += decode_netout(yhat[i][0], anchors[i], class_threshold, input_h, input_w)
    print("box_list size: ",len(boxes))
    # correct the sizes of the bounding boxes for the shape of the image
    correct_yolo_boxes(boxes, image_h, image_w, input_h, input_w)
    
    # suppress non-maximal boxes
    do_nms(boxes, 0.5)
    
    # get the details of the detected objects
    v_boxes, v_labels, v_scores = get_boxes(boxes, labels, class_threshold)
    
    # finding and clearing off the unwanted objects detected before feeding to draw boxes function
    for i in range(len(v_labels)):
        if(v_labels[i]!="person"):
            rem.append(i)
    v_boxes=[i for i in v_boxes if v_boxes.index(i) not in rem]
    v_labels=[i for i in v_labels if v_labels.index(i) not in rem]
    v_scores=[i for i in v_scores if v_scores.index(i) not in rem]
        
    # draw what we found
    min_dist=50
    draw_boxes(frame, v_boxes, v_labels, v_scores, min_dist)
    
    cv2.imshow('frame',frame)
    
    end=time.time()
    print("\nP_T_P_F :",round(end-start,1))
    
    boxes.clear()
    rem.clear()
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(749, 114), (915, 195), (378, 214), (159, 244), (464, 297), (833, 446), (151, 542), (825, 552), (670, 26), (587, 41), (505, 66), (690, 72), (456, 130), (840, 155), (415, 220)]
#
# boxes : 0 : 1 Distance : 184.708
# boxes : 0 : 2 Distance : 384.241
# boxes : 0 : 3 Distance : 604.152
# boxes : 0 : 4 Distance : 338.695
# boxes : 0 : 5 Distance : 342.462
# boxes : 0 : 6 Distance : 735.383
# boxes : 0 : 7 Distance : 444.545
# boxes : 0 : 8 Distance : 118.258
# boxes : 0 : 9 Distance : 177.688
# boxes : 0 : 10 Distance : 248.676
# boxes : 0 : 11 Distance : 72.422
# boxes : 0 : 12 Distance : 293.437
# boxes : 0 : 13 Distance : 99.81
# boxes : 0 : 14 Distance : 350.417
# boxes : 1 : 2 Distance : 537.336
# boxes : 1 : 3 Distance : 757.586
# boxes : 1 : 4 Distance : 462.391
# boxes : 1 : 5 Distance : 264.055
# boxes : 1 : 6 Distance : 839.11
# boxes : 1 : 7 Distance : 368.17
# boxes : 1 : 8 Distance : 297.634
# boxes : 1 : 9 Distance : 362.353
# boxes : 1 : 10 Distance : 429.815
# boxes : 1 : 11 Distance : 256.425
# boxes : 1 : 12 Distance : 463.58
# boxes : 1 : 13 Distance : 85.0
# boxes : 1 : 14 Distance : 500.625
# boxes : 2 : 3 Distance : 221.045
# boxes : 2 : 4 Distance : 119.52
# boxes : 2 : 5 Distance : 510.734
# boxes : 2 : 6 Distance : 398.89
# boxes : 2 : 7 Distance : 560.404
# boxes : 2 : 8 Distance : 347.287
# boxes : 2 : 9 Distance : 271.312
# boxes : 2 : 10 Distance : 195.021
# boxes : 2 : 11 Distance : 342.794
# boxes : 2 : 12 Distance : 114.63
# boxes : 2 : 13 Distance : 465.752
# boxes : 2 : 14 Distance : 37.483
# boxes : 3 : 4 Distance : 309.571
# boxes : 3 : 5 Distance : 703.619
# boxes : 3 : 6 Distance : 298.107
# boxes : 3 : 7 Distance : 733.771
# boxes : 3 : 8 Distance : 555.558
# boxes : 3 : 9 Distance : 473.701
# boxes : 3 : 10 Distance : 389.102
# boxes : 3 : 11 Distance : 558.162
# boxes : 3 : 12 Distance : 318.127
# boxes : 3 : 13 Distance : 686.791
# boxes : 3 : 14 Distance : 257.123
# boxes : 4 : 5 Distance : 397.947
# boxes : 4 : 6 Distance : 397.485
# boxes : 4 : 7 Distance : 441.98
# boxes : 4 : 8 Distance : 340.407
# boxes : 4 : 9 Distance : 284.016
# boxes : 4 : 10 Distance : 234.61
# boxes : 4 : 11 Distance : 318.906
# boxes : 4 : 12 Distance : 167.192
# boxes : 4 : 13 Distance : 401.92
# boxes : 4 : 14 Distance : 91.269
# boxes : 5 : 6 Distance : 688.723
# boxes : 5 : 7 Distance : 106.301
# boxes : 5 : 8 Distance : 450.521
# boxes : 5 : 9 Distance : 473.858
# boxes : 5 : 10 Distance : 501.98
# boxes : 5 : 11 Distance : 400.406
# boxes : 5 : 12 Distance : 491.92
# boxes : 5 : 13 Distance : 291.084
# boxes : 5 : 14 Distance : 475.184
# boxes : 6 : 7 Distance : 674.074
# boxes : 6 : 8 Distance : 731.859
# boxes : 6 : 9 Distance : 664.151
# boxes : 6 : 10 Distance : 593.205
# boxes : 6 : 11 Distance : 715.137
# boxes : 6 : 12 Distance : 512.61
# boxes : 6 : 13 Distance : 790.247
# boxes : 6 : 14 Distance : 416.389
# boxes : 7 : 8 Distance : 548.362
# boxes : 7 : 9 Distance : 563.706
# boxes : 7 : 10 Distance : 581.89
# boxes : 7 : 11 Distance : 498.623
# boxes : 7 : 12 Distance : 560.576
# boxes : 7 : 13 Distance : 397.283
# boxes : 7 : 14 Distance : 527.564
# boxes : 8 : 9 Distance : 84.345
# boxes : 8 : 10 Distance : 169.779
# boxes : 8 : 11 Distance : 50.16
# boxes : 8 : 12 Distance : 237.933
# boxes : 8 : 13 Distance : 213.403
# boxes : 8 : 14 Distance : 320.408
# boxes : 9 : 10 Distance : 85.726
# boxes : 9 : 11 Distance : 107.564
# boxes : 9 : 12 Distance : 158.373
# boxes : 9 : 13 Distance : 277.498
# boxes : 9 : 14 Distance : 248.244
# boxes : 10 : 11 Distance : 185.097
# boxes : 10 : 12 Distance : 80.604
# boxes : 10 : 13 Distance : 346.621
# boxes : 10 : 14 Distance : 178.37
# boxes : 11 : 12 Distance : 241.081
# boxes : 11 : 13 Distance : 171.432
# boxes : 11 : 14 Distance : 312.296
# boxes : 12 : 13 Distance : 384.813
# boxes : 12 : 14 Distance : 98.899
# boxes : 13 : 14 Distance : 429.942
#
# P_T_P_F : 8.5
#
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(750, 113), (915, 197), (380, 211), (415, 217), (158, 244), (460, 320), (832, 445), (150, 542), (671, 26), (587, 42), (506, 66), (692, 72), (456, 129), (840, 153)]
#
# boxes : 0 : 1 Distance : 185.151
# boxes : 0 : 2 Distance : 382.758
# boxes : 0 : 3 Distance : 350.772
# boxes : 0 : 4 Distance : 606.321
# boxes : 0 : 5 Distance : 356.299
# boxes : 0 : 6 Distance : 341.977
# boxes : 0 : 7 Distance : 737.591
# boxes : 0 : 8 Distance : 117.516
# boxes : 0 : 9 Distance : 177.792
# boxes : 0 : 10 Distance : 248.485
# boxes : 0 : 11 Distance : 71.028
# boxes : 0 : 12 Distance : 294.435
# boxes : 0 : 13 Distance : 98.489
# boxes : 1 : 2 Distance : 535.183
# boxes : 1 : 3 Distance : 500.4
# boxes : 1 : 4 Distance : 758.458
# boxes : 1 : 5 Distance : 471.332
# boxes : 1 : 6 Distance : 261.521
# boxes : 1 : 7 Distance : 839.196
# boxes : 1 : 8 Distance : 297.955
# boxes : 1 : 9 Distance : 362.78
# boxes : 1 : 10 Distance : 429.467
# boxes : 1 : 11 Distance : 255.644
# boxes : 1 : 12 Distance : 464.01
# boxes : 1 : 13 Distance : 86.954
# boxes : 2 : 3 Distance : 35.511
# boxes : 2 : 4 Distance : 224.439
# boxes : 2 : 5 Distance : 135.207
# boxes : 2 : 6 Distance : 508.979
# boxes : 2 : 7 Distance : 403.065
# boxes : 2 : 8 Distance : 344.827
# boxes : 2 : 9 Distance : 267.226
# boxes : 2 : 10 Distance : 192.096
# boxes : 2 : 11 Distance : 341.563
# boxes : 2 : 12 Distance : 111.803
# boxes : 2 : 13 Distance : 463.642
# boxes : 3 : 4 Distance : 258.414
# boxes : 3 : 5 Distance : 112.401
# boxes : 3 : 6 Distance : 475.261
# boxes : 3 : 7 Distance : 419.345
# boxes : 3 : 8 Distance : 319.401
# boxes : 3 : 9 Distance : 245.375
# boxes : 3 : 10 Distance : 176.301
# boxes : 3 : 11 Distance : 312.656
# boxes : 3 : 12 Distance : 97.082
# boxes : 3 : 13 Distance : 429.792
# boxes : 4 : 5 Distance : 311.416
# boxes : 4 : 6 Distance : 703.333
# boxes : 4 : 7 Distance : 298.107
# boxes : 4 : 8 Distance : 557.398
# boxes : 4 : 9 Distance : 474.178
# boxes : 4 : 10 Distance : 390.881
# boxes : 4 : 11 Distance : 561.017
# boxes : 4 : 12 Distance : 319.42
# boxes : 4 : 13 Distance : 688.044
# boxes : 5 : 6 Distance : 392.44
# boxes : 5 : 7 Distance : 381.293
# boxes : 5 : 8 Distance : 361.88
# boxes : 5 : 9 Distance : 305.635
# boxes : 5 : 10 Distance : 258.132
# boxes : 5 : 11 Distance : 339.6
# boxes : 5 : 12 Distance : 191.042
# boxes : 5 : 13 Distance : 415.077
# boxes : 6 : 7 Distance : 688.864
# boxes : 6 : 8 Distance : 448.867
# boxes : 6 : 9 Distance : 471.629
# boxes : 6 : 10 Distance : 499.917
# boxes : 6 : 11 Distance : 398.408
# boxes : 6 : 12 Distance : 491.154
# boxes : 6 : 13 Distance : 292.11
# boxes : 7 : 8 Distance : 733.278
# boxes : 7 : 9 Distance : 664.055
# boxes : 7 : 10 Distance : 594.401
# boxes : 7 : 11 Distance : 717.401
# boxes : 7 : 12 Distance : 514.009
# boxes : 7 : 13 Distance : 792.099
# boxes : 8 : 9 Distance : 85.51
# boxes : 8 : 10 Distance : 169.779
# boxes : 8 : 11 Distance : 50.567
# boxes : 8 : 12 Distance : 238.399
# boxes : 8 : 13 Distance : 211.4
# boxes : 9 : 10 Distance : 84.481
# boxes : 9 : 11 Distance : 109.202
# boxes : 9 : 12 Distance : 157.258
# boxes : 9 : 13 Distance : 276.279
# boxes : 10 : 11 Distance : 186.097
# boxes : 10 : 12 Distance : 80.43
# boxes : 10 : 13 Distance : 345.145
# boxes : 11 : 12 Distance : 242.786
# boxes : 11 : 13 Distance : 168.716
# boxes : 12 : 13 Distance : 384.749
#
# P_T_P_F : 9.0
#
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(751, 112), (382, 214), (418, 217), (162, 244), (456, 324), (833, 447), (140, 540), (671, 26), (587, 42), (506, 65), (693, 73), (457, 130), (839, 153), (918, 179)]
#
# boxes : 0 : 1 Distance : 382.838
# boxes : 0 : 2 Distance : 349.162
# boxes : 0 : 3 Distance : 603.61
# boxes : 0 : 4 Distance : 363.275
# boxes : 0 : 5 Distance : 344.89
# boxes : 0 : 6 Distance : 745.993
# boxes : 0 : 7 Distance : 117.456
# boxes : 0 : 8 Distance : 178.314
# boxes : 0 : 9 Distance : 249.467
# boxes : 0 : 10 Distance : 69.893
# boxes : 0 : 11 Distance : 294.551
# boxes : 0 : 12 Distance : 97.082
# boxes : 0 : 13 Distance : 179.939
# boxes : 1 : 2 Distance : 36.125
# boxes : 1 : 3 Distance : 222.036
# boxes : 1 : 4 Distance : 132.575
# boxes : 1 : 5 Distance : 507.632
# boxes : 1 : 6 Distance : 406.005
# boxes : 1 : 7 Distance : 344.768
# boxes : 1 : 8 Distance : 267.599
# boxes : 1 : 9 Distance : 193.848
# boxes : 1 : 10 Distance : 341.47
# boxes : 1 : 11 Distance : 112.61
# boxes : 1 : 12 Distance : 461.053
# boxes : 1 : 13 Distance : 537.142
# boxes : 2 : 3 Distance : 257.42
# boxes : 2 : 4 Distance : 113.547
# boxes : 2 : 5 Distance : 474.473
# boxes : 2 : 6 Distance : 426.161
# boxes : 2 : 7 Distance : 317.002
# boxes : 2 : 8 Distance : 243.282
# boxes : 2 : 9 Distance : 175.636
# boxes : 2 : 10 Distance : 310.421
# boxes : 2 : 11 Distance : 95.341
# boxes : 2 : 12 Distance : 425.837
# boxes : 2 : 13 Distance : 501.442
# boxes : 3 : 4 Distance : 304.69
# boxes : 3 : 5 Distance : 701.035
# boxes : 3 : 6 Distance : 296.816
# boxes : 3 : 7 Distance : 553.719
# boxes : 3 : 8 Distance : 470.562
# boxes : 3 : 9 Distance : 387.785
# boxes : 3 : 10 Distance : 557.855
# boxes : 3 : 11 Distance : 316.261
# boxes : 3 : 12 Distance : 683.089
# boxes : 3 : 13 Distance : 758.789
# boxes : 4 : 5 Distance : 396.558
# boxes : 4 : 6 Distance : 382.769
# boxes : 4 : 7 Distance : 367.463
# boxes : 4 : 8 Distance : 310.942
# boxes : 4 : 9 Distance : 263.782
# boxes : 4 : 10 Distance : 345.21
# boxes : 4 : 11 Distance : 194.003
# boxes : 4 : 12 Distance : 419.44
# boxes : 4 : 13 Distance : 484.22
# boxes : 5 : 6 Distance : 699.212
# boxes : 5 : 7 Distance : 451.093
# boxes : 5 : 8 Distance : 473.858
# boxes : 5 : 9 Distance : 502.845
# boxes : 5 : 10 Distance : 399.344
# boxes : 5 : 11 Distance : 491.798
# boxes : 5 : 12 Distance : 294.061
# boxes : 5 : 13 Distance : 281.157
# boxes : 6 : 7 Distance : 739.024
# boxes : 6 : 8 Distance : 669.188
# boxes : 6 : 9 Distance : 599.651
# boxes : 6 : 10 Distance : 723.808
# boxes : 6 : 11 Distance : 518.256
# boxes : 6 : 12 Distance : 798.981
# boxes : 6 : 13 Distance : 857.674
# boxes : 7 : 8 Distance : 85.51
# boxes : 7 : 9 Distance : 169.546
# boxes : 7 : 10 Distance : 51.894
# boxes : 7 : 11 Distance : 237.933
# boxes : 7 : 12 Distance : 210.602
# boxes : 7 : 13 Distance : 290.548
# boxes : 8 : 9 Distance : 84.202
# boxes : 8 : 10 Distance : 110.44
# boxes : 8 : 11 Distance : 156.984
# boxes : 8 : 12 Distance : 275.363
# boxes : 8 : 13 Distance : 358.232
# boxes : 9 : 10 Distance : 187.171
# boxes : 9 : 11 Distance : 81.4
# boxes : 9 : 12 Distance : 344.431
# boxes : 9 : 13 Distance : 427.481
# boxes : 10 : 11 Distance : 242.786
# boxes : 10 : 12 Distance : 166.481
# boxes : 10 : 13 Distance : 248.719
# boxes : 11 : 12 Distance : 382.692
# boxes : 11 : 13 Distance : 463.597
# boxes : 12 : 13 Distance : 83.169
#
# P_T_P_F : 8.3
#
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(752, 111), (385, 215), (422, 217), (162, 242), (152, 245), (453, 327), (832, 449), (137, 540), (382, 548), (671, 26), (586, 41), (508, 66), (695, 72), (457, 128), (839, 152), (919, 178)]
#
# boxes : 0 : 1 Distance : 381.451
# boxes : 0 : 2 Distance : 346.606
# boxes : 0 : 3 Distance : 604.368
# boxes : 0 : 4 Distance : 614.781
# boxes : 0 : 5 Distance : 368.859
# boxes : 0 : 6 Distance : 347.338
# boxes : 0 : 7 Distance : 749.844
# boxes : 0 : 8 Distance : 572.598
# boxes : 0 : 9 Distance : 117.414
# boxes : 0 : 10 Distance : 180.155
# boxes : 0 : 11 Distance : 248.115
# boxes : 0 : 12 Distance : 69.065
# boxes : 0 : 13 Distance : 295.489
# boxes : 0 : 14 Distance : 96.177
# boxes : 0 : 15 Distance : 179.939
# boxes : 1 : 2 Distance : 37.054
# boxes : 1 : 3 Distance : 224.629
# boxes : 1 : 4 Distance : 234.923
# boxes : 1 : 5 Distance : 131.027
# boxes : 1 : 6 Distance : 504.544
# boxes : 1 : 7 Distance : 408.814
# boxes : 1 : 8 Distance : 333.014
# boxes : 1 : 9 Distance : 342.808
# boxes : 1 : 10 Distance : 265.851
# boxes : 1 : 11 Distance : 193.21
# boxes : 1 : 12 Distance : 341.393
# boxes : 1 : 13 Distance : 112.929
# boxes : 1 : 14 Distance : 458.35
# boxes : 1 : 15 Distance : 535.28
# boxes : 2 : 3 Distance : 261.199
# boxes : 2 : 4 Distance : 271.448
# boxes : 2 : 5 Distance : 114.285
# boxes : 2 : 6 Distance : 471.088
# boxes : 2 : 7 Distance : 430.76
# boxes : 2 : 8 Distance : 333.408
# boxes : 2 : 9 Distance : 313.818
# boxes : 2 : 10 Distance : 240.566
# boxes : 2 : 11 Distance : 173.773
# boxes : 2 : 12 Distance : 309.118
# boxes : 2 : 13 Distance : 95.635
# boxes : 2 : 14 Distance : 422.036
# boxes : 2 : 15 Distance : 498.528
# boxes : 3 : 4 Distance : 10.44
# boxes : 3 : 5 Distance : 303.16
# boxes : 3 : 6 Distance : 701.248
# boxes : 3 : 7 Distance : 299.047
# boxes : 3 : 8 Distance : 376.877
# boxes : 3 : 9 Distance : 552.935
# boxes : 3 : 10 Distance : 469.23
# boxes : 3 : 11 Distance : 388.191
# boxes : 3 : 12 Distance : 559.454
# boxes : 3 : 13 Distance : 316.261
# boxes : 3 : 14 Distance : 682.956
# boxes : 3 : 15 Distance : 759.701
# boxes : 4 : 5 Distance : 311.97
# boxes : 4 : 6 Distance : 709.941
# boxes : 4 : 7 Distance : 295.381
# boxes : 4 : 8 Distance : 380.406
# boxes : 4 : 9 Distance : 563.313
# boxes : 4 : 10 Distance : 479.554
# boxes : 4 : 11 Distance : 398.468
# boxes : 4 : 12 Distance : 569.893
# boxes : 4 : 13 Distance : 326.671
# boxes : 4 : 14 Distance : 693.266
# boxes : 4 : 15 Distance : 769.921
# boxes : 5 : 6 Distance : 398.152
# boxes : 5 : 7 Distance : 381.084
# boxes : 5 : 8 Distance : 232.125
# boxes : 5 : 9 Distance : 371.652
# boxes : 5 : 10 Distance : 315.412
# boxes : 5 : 11 Distance : 266.732
# boxes : 5 : 12 Distance : 351.552
# boxes : 5 : 13 Distance : 199.04
# boxes : 5 : 14 Distance : 423.817
# boxes : 5 : 15 Distance : 489.241
# boxes : 6 : 7 Distance : 700.932
# boxes : 6 : 8 Distance : 460.761
# boxes : 6 : 9 Distance : 452.604
# boxes : 6 : 10 Distance : 476.424
# boxes : 6 : 11 Distance : 501.662
# boxes : 6 : 12 Distance : 401.121
# boxes : 6 : 13 Distance : 493.625
# boxes : 6 : 14 Distance : 297.082
# boxes : 6 : 15 Distance : 284.623
# boxes : 7 : 8 Distance : 245.131
# boxes : 7 : 9 Distance : 741.183
# boxes : 7 : 10 Distance : 671.269
# boxes : 7 : 11 Distance : 601.928
# boxes : 7 : 12 Distance : 728.277
# boxes : 7 : 13 Distance : 521.674
# boxes : 7 : 14 Distance : 802.09
# boxes : 7 : 15 Distance : 861.724
# boxes : 8 : 9 Distance : 596.662
# boxes : 8 : 10 Distance : 546.503
# boxes : 8 : 11 Distance : 498.197
# boxes : 8 : 12 Distance : 569.689
# boxes : 8 : 13 Distance : 426.644
# boxes : 8 : 14 Distance : 604.702
# boxes : 8 : 15 Distance : 652.127
# boxes : 9 : 10 Distance : 86.313
# boxes : 9 : 11 Distance : 167.836
# boxes : 9 : 12 Distance : 51.884
# boxes : 9 : 13 Distance : 237.065
# boxes : 9 : 14 Distance : 210.0
# boxes : 9 : 15 Distance : 290.875
# boxes : 10 : 11 Distance : 81.908
# boxes : 10 : 12 Distance : 113.323
# boxes : 10 : 13 Distance : 155.596
# boxes : 10 : 14 Distance : 276.279
# boxes : 10 : 15 Distance : 360.081
# boxes : 11 : 12 Distance : 187.096
# boxes : 11 : 13 Distance : 80.281
# boxes : 11 : 14 Distance : 341.99
# boxes : 11 : 15 Distance : 425.987
# boxes : 12 : 13 Distance : 244.499
# boxes : 12 : 14 Distance : 164.73
# boxes : 12 : 15 Distance : 247.814
# boxes : 13 : 14 Distance : 382.753
# boxes : 13 : 15 Distance : 464.698
# boxes : 14 : 15 Distance : 84.119
#
# P_T_P_F : 8.5
#
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(752, 111), (385, 215), (425, 216), (151, 249), (452, 327), (831, 451), (135, 541), (383, 547), (670, 27), (585, 42), (510, 66), (696, 74), (457, 128), (839, 149), (919, 176)]
#
# boxes : 0 : 1 Distance : 381.451
# boxes : 0 : 2 Distance : 343.444
# boxes : 0 : 3 Distance : 616.64
# boxes : 0 : 4 Distance : 369.67
# boxes : 0 : 5 Distance : 349.057
# boxes : 0 : 6 Distance : 752.057
# boxes : 0 : 7 Distance : 571.189
# boxes : 0 : 8 Distance : 117.388
# boxes : 0 : 9 Distance : 180.693
# boxes : 0 : 10 Distance : 246.148
# boxes : 0 : 11 Distance : 67.119
# boxes : 0 : 12 Distance : 295.489
# boxes : 0 : 13 Distance : 94.937
# boxes : 0 : 14 Distance : 179.204
# boxes : 1 : 2 Distance : 40.012
# boxes : 1 : 3 Distance : 236.457
# boxes : 1 : 4 Distance : 130.511
# boxes : 1 : 5 Distance : 504.591
# boxes : 1 : 6 Distance : 410.824
# boxes : 1 : 7 Distance : 332.006
# boxes : 1 : 8 Distance : 341.422
# boxes : 1 : 9 Distance : 264.441
# boxes : 1 : 10 Distance : 194.489
# boxes : 1 : 11 Distance : 341.47
# boxes : 1 : 12 Distance : 112.929
# boxes : 1 : 13 Distance : 458.772
# boxes : 1 : 14 Distance : 535.422
# boxes : 2 : 3 Distance : 275.98
# boxes : 2 : 4 Distance : 114.237
# boxes : 2 : 5 Distance : 469.107
# boxes : 2 : 6 Distance : 435.574
# boxes : 2 : 7 Distance : 333.654
# boxes : 2 : 8 Distance : 309.429
# boxes : 2 : 9 Distance : 236.381
# boxes : 2 : 10 Distance : 172.409
# boxes : 2 : 11 Distance : 305.949
# boxes : 2 : 12 Distance : 93.638
# boxes : 2 : 13 Distance : 419.386
# boxes : 2 : 14 Distance : 495.617
# boxes : 3 : 4 Distance : 310.942
# boxes : 3 : 5 Distance : 709.369
# boxes : 3 : 6 Distance : 292.438
# boxes : 3 : 7 Distance : 377.661
# boxes : 3 : 8 Distance : 564.486
# boxes : 3 : 9 Distance : 480.838
# boxes : 3 : 10 Distance : 402.952
# boxes : 3 : 11 Distance : 572.407
# boxes : 3 : 12 Distance : 329.055
# boxes : 3 : 13 Distance : 695.229
# boxes : 3 : 14 Distance : 771.462
# boxes : 4 : 5 Distance : 398.769
# boxes : 4 : 6 Distance : 382.472
# boxes : 4 : 7 Distance : 230.567
# boxes : 4 : 8 Distance : 370.842
# boxes : 4 : 9 Distance : 314.506
# boxes : 4 : 10 Distance : 267.367
# boxes : 4 : 11 Distance : 351.49
# boxes : 4 : 12 Distance : 199.063
# boxes : 4 : 13 Distance : 425.973
# boxes : 4 : 14 Distance : 490.805
# boxes : 5 : 6 Distance : 701.795
# boxes : 5 : 7 Distance : 458.17
# boxes : 5 : 8 Distance : 453.538
# boxes : 5 : 9 Distance : 477.281
# boxes : 5 : 10 Distance : 501.264
# boxes : 5 : 11 Distance : 400.442
# boxes : 5 : 12 Distance : 494.171
# boxes : 5 : 13 Distance : 302.106
# boxes : 5 : 14 Distance : 288.737
# boxes : 6 : 7 Distance : 248.073
# boxes : 6 : 8 Distance : 741.904
# boxes : 6 : 9 Distance : 671.938
# boxes : 6 : 10 Distance : 605.186
# boxes : 6 : 11 Distance : 729.938
# boxes : 6 : 12 Distance : 523.692
# boxes : 6 : 13 Distance : 805.779
# boxes : 6 : 14 Distance : 864.801
# boxes : 7 : 8 Distance : 593.944
# boxes : 7 : 9 Distance : 543.902
# boxes : 7 : 10 Distance : 497.484
# boxes : 7 : 11 Distance : 567.184
# boxes : 7 : 12 Distance : 425.484
# boxes : 7 : 13 Distance : 605.26
# boxes : 7 : 14 Distance : 651.872
# boxes : 8 : 9 Distance : 86.313
# boxes : 8 : 10 Distance : 164.685
# boxes : 8 : 11 Distance : 53.712
# boxes : 8 : 12 Distance : 235.733
# boxes : 8 : 13 Distance : 208.435
# boxes : 8 : 14 Distance : 290.176
# boxes : 9 : 10 Distance : 78.746
# boxes : 9 : 11 Distance : 115.521
# boxes : 9 : 12 Distance : 154.208
# boxes : 9 : 13 Distance : 275.617
# boxes : 9 : 14 Distance : 359.878
# boxes : 10 : 11 Distance : 186.172
# boxes : 10 : 12 Distance : 81.566
# boxes : 10 : 13 Distance : 339.308
# boxes : 10 : 14 Distance : 423.534
# boxes : 11 : 12 Distance : 245.024
# boxes : 11 : 13 Distance : 161.474
# boxes : 11 : 14 Distance : 245.22
# boxes : 12 : 13 Distance : 382.577
# boxes : 12 : 14 Distance : 464.487
# boxes : 13 : 14 Distance : 84.433
#
# P_T_P_F : 8.5
#
# Captured_frame_shape : (540, 960, 3)
# Frame_Feed_To_Model  : (416, 416, 3)
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# box_list size:  10647
#
# Mid point coordinates :
# [(751, 110), (385, 214), (427, 215), (144, 249), (451, 325), (833, 460), (132, 543), (380, 548), (670, 27), (585, 41), (510, 66), (698, 74), (458, 128), (838, 147)]
#
# boxes : 0 : 1 Distance : 380.489
# boxes : 0 : 2 Distance : 340.589
# boxes : 0 : 3 Distance : 622.712
# boxes : 0 : 4 Distance : 369.087
# boxes : 0 : 5 Distance : 359.477
# boxes : 0 : 6 Distance : 755.414
# boxes : 0 : 7 Distance : 574.008
# boxes : 0 : 8 Distance : 115.974
# boxes : 0 : 9 Distance : 179.769
# boxes : 0 : 10 Distance : 244.984
# boxes : 0 : 11 Distance : 64.07
# boxes : 0 : 12 Distance : 293.552
# boxes : 0 : 13 Distance : 94.541
# boxes : 1 : 2 Distance : 42.012
# boxes : 1 : 3 Distance : 243.528
# boxes : 1 : 4 Distance : 129.139
# boxes : 1 : 5 Distance : 511.097
# boxes : 1 : 6 Distance : 415.03
# boxes : 1 : 7 Distance : 334.037
# boxes : 1 : 8 Distance : 340.872
# boxes : 1 : 9 Distance : 264.441
# boxes : 1 : 10 Distance : 193.724
# boxes : 1 : 11 Distance : 342.883
# boxes : 1 : 12 Distance : 112.805
# boxes : 1 : 13 Distance : 457.928
# boxes : 2 : 3 Distance : 285.035
# boxes : 2 : 4 Distance : 112.588
# boxes : 2 : 5 Distance : 474.195
# boxes : 2 : 6 Distance : 441.145
# boxes : 2 : 7 Distance : 336.3
# boxes : 2 : 8 Distance : 307.234
# boxes : 2 : 9 Distance : 235.032
# boxes : 2 : 10 Distance : 170.558
# boxes : 2 : 11 Distance : 305.486
# boxes : 2 : 12 Distance : 92.358
# boxes : 2 : 13 Distance : 416.587
# boxes : 3 : 4 Distance : 316.267
# boxes : 3 : 5 Distance : 720.584
# boxes : 3 : 6 Distance : 294.245
# boxes : 3 : 7 Distance : 380.916
# boxes : 3 : 8 Distance : 570.929
# boxes : 3 : 9 Distance : 487.591
# boxes : 3 : 10 Distance : 409.2
# boxes : 3 : 11 Distance : 580.983
# boxes : 3 : 12 Distance : 336.507
# boxes : 3 : 13 Distance : 701.456
# boxes : 4 : 5 Distance : 405.153
# boxes : 4 : 6 Distance : 386.374
# boxes : 4 : 7 Distance : 234.03
# boxes : 4 : 8 Distance : 369.818
# boxes : 4 : 9 Distance : 314.025
# boxes : 4 : 10 Distance : 265.635
# boxes : 4 : 11 Distance : 352.151
# boxes : 4 : 12 Distance : 197.124
# boxes : 4 : 13 Distance : 425.973
# boxes : 5 : 6 Distance : 705.897
# boxes : 5 : 7 Distance : 461.468
# boxes : 5 : 8 Distance : 462.664
# boxes : 5 : 9 Distance : 486.893
# boxes : 5 : 10 Distance : 509.475
# boxes : 5 : 11 Distance : 408.927
# boxes : 5 : 12 Distance : 500.848
# boxes : 5 : 13 Distance : 313.04
# boxes : 6 : 7 Distance : 248.05
# boxes : 6 : 8 Distance : 745.453
# boxes : 6 : 9 Distance : 676.175
# boxes : 6 : 10 Distance : 608.616
# boxes : 6 : 11 Distance : 735.063
# boxes : 6 : 12 Distance : 527.732
# boxes : 6 : 13 Distance : 809.476
# boxes : 7 : 8 Distance : 596.273
# boxes : 7 : 9 Distance : 546.877
# boxes : 7 : 10 Distance : 499.223
# boxes : 7 : 11 Distance : 570.789
# boxes : 7 : 12 Distance : 427.181
# boxes : 7 : 13 Distance : 608.741
# boxes : 8 : 9 Distance : 86.145
# boxes : 8 : 10 Distance : 164.685
# boxes : 8 : 11 Distance : 54.708
# boxes : 8 : 12 Distance : 234.83
# boxes : 8 : 13 Distance : 206.456
# boxes : 9 : 10 Distance : 79.057
# boxes : 9 : 11 Distance : 117.72
# boxes : 9 : 12 Distance : 153.942
# boxes : 9 : 13 Distance : 274.308
# boxes : 10 : 11 Distance : 188.17
# boxes : 10 : 12 Distance : 80.92
# boxes : 10 : 13 Distance : 337.854
# boxes : 11 : 12 Distance : 246.0
# boxes : 11 : 13 Distance : 157.889
# boxes : 12 : 13 Distance : 380.475
#
# P_T_P_F : 8.5

# %%
math.sqrt?
